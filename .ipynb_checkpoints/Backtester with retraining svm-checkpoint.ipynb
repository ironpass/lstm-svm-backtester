# %%
from sklearn import svm, datasets
from sklearn.svm import NuSVC, SVC
import os
import math
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA

from tqdm import tqdm

# %%
debug_training_set = None
debug_target = None

def create_model():
    
    model = svm.NuSVC(gamma='scale', nu=0.65)
    
    return model

def retrain(training_set, target):
    np_training_set = np.array(training_set)
    np_training_set = np.reshape(np_training_set,(np_training_set.shape[0], 40))
    np_target = np.array(target)[:,1]
    
    model = create_model()
    
    global debug_training_set
    global debug_target
    debug_training_set = np_training_set
    debug_target = np_target
    
    model = model.fit(np_training_set, np_target)
    print("Retraining....")
    
    return model

# %%
def init_params(testing_hourly, backtest_params):
    params = {
        "balance":1000,
        "volume": backtest_params["volume"]*10000, #10,000 == 1 lot
        "tp": backtest_params["tp"], # 400 pips
        "sl": backtest_params["sl"], # 400 pips

        "hour_counter":0,
        "day_count":0,
        "today_positions":[],
        "model_inputs":[[0,0,0,0]],

        "polarity":0,
        "tp_boundary":0,
        "sl_boundary":0,
        
        "latest_date":testing_hourly["<DATE>"][0],
        "minimum_training_set":1411,
        "is_retrain":backtest_params["is_retrain"],
        "retrain_interval":200
    }
    return params

def close_order(order):
    order["open_position"]=None
    order["age"] = 0
    order["type"] = None
    order["tp_pos"] = None
    order["sl_pos"] = None
    order["close_status"] = None
    order["opening_time"] = None
    order["closing_time"] = None

def is_there_an_order(order):
    if(order["open_position"]!=None):
        return True
    return False

def order_aging(order):
    if(is_there_an_order(order)):
        order["age"]+=1

def calculateMargin(open_position, close_position, order_type, order_volume):
    if (order_type == "BUY"):
        return (close_position - open_position) * order_volume
    elif(order_type == "SELL"):
        return (open_position - close_position) * order_volume
    return 0

def hourly_to_daily(today_positions):
    today_open = today_positions[0][0]
    today_high = np.max(today_positions) 
    today_low = np.min(today_positions)
    today_close = today_positions[-1][3]
    return [today_open, today_high, today_low, today_close]

def update(params, record):
    if(record["<DATE>"] != params["latest_date"]):
        params["day_count"] += 1
        params["hour_counter"] = 0
        params["model_inputs"].append(hourly_to_daily(params["today_positions"]))
        params["today_positions"] = []
        
    params["today_positions"].append([record["<OPEN>"], record["<HIGH>"], record["<LOW>"], record["<CLOSE>"]])
    params["hour_counter"]+=1

        
def scale_diff(next_val, curr_val):
    scaled_diff = min(1, next_val-curr_val)
    scaled_diff = max(-1, scaled_diff)
    return scaled_diff

def find_diff(model_inputs):
    diff_model_inputs = []
    for i in range(len(model_inputs[:-1])):
        curr_record = model_inputs[i]
        next_record = model_inputs[i+1]
        
        open_diff = scale_diff(next_record[0], curr_record[0])
        high_diff = scale_diff(next_record[1], curr_record[1])
        low_diff = scale_diff(next_record[2], curr_record[2])
        close_diff = scale_diff(next_record[3], curr_record[3])
        
        diff_model_inputs.append([open_diff,high_diff,low_diff,close_diff])
    return diff_model_inputs


def update_volume(balance, avg_swing, static_scale):
    return ((balance * 0.1) / avg_swing) * static_scale

def update_model_inputs(diff_model_inputs, retrain_input, retrain_target):
    if(len(retrain_input) >= 1401):
        del retrain_input[:1]
        
    retrain_input.append(diff_model_inputs)
    
    if(len(retrain_input) > 1):
        if(len(retrain_target) >= 1400):
            del retrain_target[:1]
        retrain_target.append(find_target_for_retrain(diff_model_inputs[-1]))

def find_target_for_retrain(diff_model_input):    
    if(diff_model_input[1] >= -1*diff_model_input[2]):
        return [0,1]
    else:
        return [1,0]
        
def ask_model_for_signal(model, params, record, order_signal, retrain_input, retrain_target):
    diff_model_inputs = find_diff(params["model_inputs"])
    if(len(params["model_inputs"])>=11 and params["day_count"] >= params["minimum_training_set"]):
        transformed_diff_model_inputs = np.reshape(diff_model_inputs, (1, 40))

        if(params["day_count"] >= params["minimum_training_set"] and (params["day_count"]-11) % params["retrain_interval"] == 0):
            if(params["is_retrain"] == "always"):
                model = retrain(retrain_input[:-1], retrain_target)
            elif(params["is_retrain"] == "once"):
                model = retrain(retrain_input[:-1], retrain_target)
                params["is_retrain"] = "trained"

        order_signal = model.predict(transformed_diff_model_inputs)
        params["model_inputs"] = params["model_inputs"][1:]

        update_model_inputs(diff_model_inputs, retrain_input, retrain_target)
        
        
    elif(len(params["model_inputs"])>=11):
        params["latest_date"] = record["<DATE>"]
        params["model_inputs"] = params["model_inputs"][1:]
        
        update_model_inputs(diff_model_inputs, retrain_input, retrain_target)
    else:
        params["latest_date"] = record["<DATE>"]

    return order_signal, model
    
def should_order_be_closed(order, params, record, order_history):
    close_order_event = {}
    if(order["type"]=="BUY"):
        params["polarity"] = 1
        params["tp_boundary"] = record["<HIGH>"]
        params["sl_boundary"] = record["<LOW>"]
    elif(order["type"]=="SELL"):
        params["polarity"] = -1
        params["tp_boundary"] = record["<LOW>"]
        params["sl_boundary"] = record["<HIGH>"]
        
    if(is_there_an_order(order)):
        profit = 0
        closing_position = 0
        if(params["sl_boundary"]*params["polarity"] <= order["sl_pos"]*params["polarity"]):
            profit = calculateMargin(order["open_position"], order["sl_pos"], order["type"], params["volume"])
            params["balance"] += profit
            order["close_status"] = "sl"
            order["closing_time"] = record["<DATE>"]+"-"+record["<TIME>"]
            closing_position = order["sl_pos"]
        elif(params["tp_boundary"]*params["polarity"] >= order["tp_pos"]*params["polarity"]):
            profit =  calculateMargin(order["open_position"], order["tp_pos"], order["type"], params["volume"])
            params["balance"] += profit
            order["close_status"] = "tp"
            order["closing_time"] = record["<DATE>"]+"-"+record["<TIME>"]
            closing_position = record["tp_pos"]
        # In case neither sl or tp is reached, the order will be closed at the end of the day
        elif (record["<DATE>"] != params["latest_date"]):
            profit =  calculateMargin(order["open_position"], record["<OPEN>"], order["type"], params["volume"])
            params["balance"] += profit
            order["close_status"] = "eotd"
            order["closing_time"] = record["<DATE>"]+"-"+record["<TIME>"]
            closing_position = record["<CLOSE>"]
            
        if(not order["close_status"] is None):
            order_history.append(order.copy())
            close_order(order)
            
            close_order_event = {
                "closing_position":closing_position,
                "profit":profit,
                "datetime":record["<DATE>"]
            }
    return close_order_event

# %%
def evaluate(testing_hourly, model, backtest_params):
    order = {
        "open_position":None,
        "age":0,
        "type":None,
        "tp_pos":None,
        "sl_pos":None,
        "close_status":None,
        "opening_time":None,
        "closing_time":None
    }
    
    params = init_params(testing_hourly, backtest_params)
    
    balance_history = [params["balance"]]
    order_history = []
    order_signal = None
    
    retrain_input = []
    retrain_target = []
    
    open_order_events = []
    close_order_events = []
    
    
    
    for idx, record in tqdm(testing_hourly[:-1].iterrows()):
        
        open_order_event = {}
        close_order_event = {}
        
        # Update params hourly
        update(params, record)

        # Call the model for a signal
        order_signal, model = ask_model_for_signal(model, params, record, order_signal, retrain_input, retrain_target)

        # Check whether sl or tp is reached
        close_order_event = should_order_be_closed(order, params, record, order_history)

        # Open an order
        if(not order_signal is None):
            if ((not is_there_an_order(order)) and (record["<DATE>"] != params["latest_date"])):
                order["opening_time"] = record["<DATE>"]+"-"+record["<TIME>"]
                order["open_position"] = record["<OPEN>"]       
                # Classification Model Logic
                if(order_signal[0] == 0):
                    order["type"] = "SELL"
                elif(order_signal[0] == 1):
                    order["type"] = "BUY"
                else:
                    order["type"] = None

                order["tp_pos"] = order["open_position"]+params["tp"] if order["type"]=="BUY" else order["open_position"]-params["tp"]
                order["sl_pos"] = order["open_position"]-params["sl"] if order["type"]=="BUY" else order["open_position"]+params["sl"]
                
                open_order_event = {
                    "open_position":order["open_position"],
                    "order_type":order["type"],
                    "volume":params["volume"],
                    "datetime":record["<DATE>"]
                }
                
            params["latest_date"] = record["<DATE>"]
        
        balance_history.append(params["balance"])
        
        # Let the order ages
        order_aging(order)
        
        open_order_events.append(open_order_event)
        close_order_events.append(close_order_event)
    
    open_order_events.append({})
    close_order_events.append({})
    
    graph = pd.DataFrame({
        "date":testing_hourly["<DATE>"],
        "open":testing_hourly["<OPEN>"],
        "high":testing_hourly["<HIGH>"],
        "low":testing_hourly["<LOW>"],
        "close":testing_hourly["<CLOSE>"],
        "volume":testing_hourly["<TICKVOL>"],
        "balance_history":balance_history,
        "open_order_events":open_order_events,
        "close_order_events":close_order_events
    })
            
    return graph.to_dict('records')

# %%
def backtest(is_retrain, volume, sl, tp):
    backtest_params = {
        "is_retrain": "always" if(is_retrain) else "once",
        "volume":volume,
        "sl":sl,
        "tp":tp
    }
    
    # currency_pairs = ['USDJPY', 'AUDUSD', 'EURUSD', 'GBPUSD', 'NZDUSD', 'USDCAD', 'USDCHF']

    num_step = 10
    skip_step = 1
    test_range_limit = 200


    currency_pair = 'EURJPY'

    file_path = "oneshot_dataset/"+currency_pair+"_H1_200910290000_201901252300.csv"
    testing_hourly = pd.read_csv(file_path, sep='\t')
    if ("JPY" in file_path):
        testing_hourly['<OPEN>'] = testing_hourly['<OPEN>']/100
        testing_hourly['<HIGH>'] = testing_hourly['<HIGH>']/100
        testing_hourly['<LOW>'] = testing_hourly['<LOW>']/100
        testing_hourly['<CLOSE>'] = testing_hourly['<CLOSE>']/100

    graph = evaluate(testing_hourly, create_model(), backtest_params)
    
    return graph

graph = backtest(True, 1, 400, 400)
# Out:
# 33129it [00:05, 6469.11it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-204a4f2bfe7f> in <module>()
#      28     return graph
#      29
# ---> 30 graph = backtest(True, 1, 400, 400)
#
# <ipython-input-5-204a4f2bfe7f> in backtest(is_retrain, volume, sl, tp)
#      24         testing_hourly['<CLOSE>'] = testing_hourly['<CLOSE>']/100
#      25
# ---> 26     graph = evaluate(testing_hourly, create_model(), backtest_params)
#      27
#      28     return graph
#
# <ipython-input-4-048628598610> in evaluate(testing_hourly, model, backtest_params)
#      34
#      35         # Call the model for a signal
# ---> 36         order_signal, model = ask_model_for_signal(model, params, record, order_signal, retrain_input, retrain_target)
#      37
#      38         # Check whether sl or tp is reached
#
# <ipython-input-3-d158e7521dfc> in ask_model_for_signal(model, params, record, order_signal, retrain_input, retrain_target)
#     113         if(params["day_count"] >= params["minimum_training_set"] and (params["day_count"]-11) % params["retrain_interval"] == 0):
#     114             if(params["is_retrain"] == "always"):
# --> 115                 model = retrain(retrain_input[:-1], retrain_target)
#     116             elif(params["is_retrain"] == "once"):
#     117                 model = retrain(retrain_input[:-1], retrain_target)
#
# <ipython-input-2-df6cecb973fd> in retrain(training_set, target)
#      20     debug_target = np_target
#      21
# ---> 22     model = model.fit(np_training_set, np_target)
#      23     print("Retraining....")
#      24
#
# c:\users\ood\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# c:\users\ood\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# sklearn\svm\libsvm.pyx in sklearn.svm.libsvm.fit()
#
# TypeError: must be real number, not str

# %%
print(graph[-1]["balance_history"])
balance_hist = []
for i in graph:
    balance_hist.append(i["balance_history"])
plt.plot(balance_hist)

# %%
model = create_model()

model.fit([[1,2,3,4],[5,6,7,8]], [0,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-9a8068553d9a> in <module>()
#       1 model = create_model()
#       2
# ----> 3 model.fit([[1,2,3,4],[5,6,7,8]], [0,1])
#
# c:\users\ood\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# c:\users\ood\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# sklearn\svm\libsvm.pyx in sklearn.svm.libsvm.fit()
#
# TypeError: must be real number, not str

# %%
print(balance_history[-1])
plt.plot(balance_history)
# Out:
# 9508.750000000173

# %%
order_history
# Out:
# [{'position': 1.30245,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.30245,
#   'sl_pos': -2.6975499999999997,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.03-00:00:00',
#   'closing_time': '2015.04.06-00:00:00'},
#  {'position': 1.30774,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69226,
#   'sl_pos': 5.30774,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.06-00:00:00',
#   'closing_time': '2015.04.07-00:00:00'},
#  {'position': 1.3054,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6946000000000003,
#   'sl_pos': 5.3054,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.07-00:00:00',
#   'closing_time': '2015.04.08-00:00:00'},
#  {'position': 1.3005700000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6994299999999996,
#   'sl_pos': 5.3005700000000004,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.08-00:00:00',
#   'closing_time': '2015.04.09-00:00:00'},
#  {'position': 1.2948300000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70517,
#   'sl_pos': 5.29483,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.09-00:00:00',
#   'closing_time': '2015.04.10-00:00:00'},
#  {'position': 1.2851400000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71486,
#   'sl_pos': 5.28514,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.10-00:00:00',
#   'closing_time': '2015.04.13-00:00:00'},
#  {'position': 1.27451,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7254899999999997,
#   'sl_pos': 5.27451,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.13-00:00:00',
#   'closing_time': '2015.04.14-00:00:00'},
#  {'position': 1.26925,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.73075,
#   'sl_pos': 5.2692499999999995,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.14-00:00:00',
#   'closing_time': '2015.04.15-00:00:00'},
#  {'position': 1.27178,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27178,
#   'sl_pos': -2.7282200000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.15-00:00:00',
#   'closing_time': '2015.04.16-00:00:00'},
#  {'position': 1.27353,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27353,
#   'sl_pos': -2.72647,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.16-00:00:00',
#   'closing_time': '2015.04.17-00:00:00'},
#  {'position': 1.27977,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27977,
#   'sl_pos': -2.72023,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.17-00:00:00',
#   'closing_time': '2015.04.20-00:00:00'},
#  {'position': 1.28536,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28536,
#   'sl_pos': -2.71464,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.20-00:00:00',
#   'closing_time': '2015.04.21-00:00:00'},
#  {'position': 1.27998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72002,
#   'sl_pos': 5.27998,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.21-00:00:00',
#   'closing_time': '2015.04.22-00:00:00'},
#  {'position': 1.28416,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28416,
#   'sl_pos': -2.71584,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.22-00:00:00',
#   'closing_time': '2015.04.23-00:00:00'},
#  {'position': 1.2855100000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28551,
#   'sl_pos': -2.7144899999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.23-00:00:00',
#   'closing_time': '2015.04.24-00:00:00'},
#  {'position': 1.2943799999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29438,
#   'sl_pos': -2.70562,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.24-00:00:00',
#   'closing_time': '2015.04.27-00:00:00'},
#  {'position': 1.2915999999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7084,
#   'sl_pos': 5.2916,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.27-00:00:00',
#   'closing_time': '2015.04.28-00:00:00'},
#  {'position': 1.29624,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29624,
#   'sl_pos': -2.70376,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.28-00:00:00',
#   'closing_time': '2015.04.29-00:00:00'},
#  {'position': 1.3046799999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.304679999999999,
#   'sl_pos': -2.69532,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.29-00:00:00',
#   'closing_time': '2015.04.30-00:00:00'},
#  {'position': 1.32449,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.32449,
#   'sl_pos': -2.67551,
#   'close_status': 'eotd',
#   'opening_time': '2015.04.30-00:00:00',
#   'closing_time': '2015.05.01-00:00:00'},
#  {'position': 1.3395400000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.33954,
#   'sl_pos': -2.6604599999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.01-00:00:00',
#   'closing_time': '2015.05.04-00:00:00'},
#  {'position': 1.34565,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65435,
#   'sl_pos': 5.34565,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.04-00:00:00',
#   'closing_time': '2015.05.05-00:00:00'},
#  {'position': 1.33826,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.66174,
#   'sl_pos': 5.33826,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.05-00:00:00',
#   'closing_time': '2015.05.06-00:00:00'},
#  {'position': 1.3405799999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34058,
#   'sl_pos': -2.65942,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.06-00:00:00',
#   'closing_time': '2015.05.07-00:00:00'},
#  {'position': 1.35532,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35532,
#   'sl_pos': -2.64468,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.07-00:00:00',
#   'closing_time': '2015.05.08-00:00:00'},
#  {'position': 1.3488299999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6511700000000005,
#   'sl_pos': 5.3488299999999995,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.08-00:00:00',
#   'closing_time': '2015.05.11-00:00:00'},
#  {'position': 1.3405700000000003,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6594299999999995,
#   'sl_pos': 5.3405700000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.11-00:00:00',
#   'closing_time': '2015.05.12-00:00:00'},
#  {'position': 1.3394,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3393999999999995,
#   'sl_pos': -2.6606,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.12-00:00:00',
#   'closing_time': '2015.05.13-00:00:00'},
#  {'position': 1.34386,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6561399999999997,
#   'sl_pos': 5.34386,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.13-00:00:00',
#   'closing_time': '2015.05.14-00:00:00'},
#  {'position': 1.35258,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35258,
#   'sl_pos': -2.6474200000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.14-00:00:00',
#   'closing_time': '2015.05.15-00:00:00'},
#  {'position': 1.35928,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35928,
#   'sl_pos': -2.64072,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.15-00:00:00',
#   'closing_time': '2015.05.18-00:00:00'},
#  {'position': 1.36577,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3657699999999995,
#   'sl_pos': -2.63423,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.18-00:00:00',
#   'closing_time': '2015.05.19-00:00:00'},
#  {'position': 1.35726,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64274,
#   'sl_pos': 5.35726,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.19-00:00:00',
#   'closing_time': '2015.05.20-00:00:00'},
#  {'position': 1.3455200000000003,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6544799999999995,
#   'sl_pos': 5.3455200000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.20-00:00:00',
#   'closing_time': '2015.05.21-00:00:00'},
#  {'position': 1.34565,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34565,
#   'sl_pos': -2.65435,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.21-00:00:00',
#   'closing_time': '2015.05.22-00:00:00'},
#  {'position': 1.34486,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6551400000000003,
#   'sl_pos': 5.34486,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.22-00:00:00',
#   'closing_time': '2015.05.25-00:00:00'},
#  {'position': 1.33701,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6629899999999997,
#   'sl_pos': 5.33701,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.25-00:00:00',
#   'closing_time': '2015.05.26-00:00:00'},
#  {'position': 1.33415,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.66585,
#   'sl_pos': 5.33415,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.26-00:00:00',
#   'closing_time': '2015.05.27-00:00:00'},
#  {'position': 1.3384,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3384,
#   'sl_pos': -2.6616,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.27-00:00:00',
#   'closing_time': '2015.05.28-00:00:00'},
#  {'position': 1.3480100000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34801,
#   'sl_pos': -2.6519899999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.28-00:00:00',
#   'closing_time': '2015.05.29-00:00:00'},
#  {'position': 1.35696,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35696,
#   'sl_pos': -2.64304,
#   'close_status': 'eotd',
#   'opening_time': '2015.05.29-00:00:00',
#   'closing_time': '2015.06.01-00:00:00'},
#  {'position': 1.3627600000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36276,
#   'sl_pos': -2.63724,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.01-00:00:00',
#   'closing_time': '2015.06.02-00:00:00'},
#  {'position': 1.36315,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36315,
#   'sl_pos': -2.63685,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.02-00:00:00',
#   'closing_time': '2015.06.03-00:00:00'},
#  {'position': 1.3838,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3838,
#   'sl_pos': -2.6162,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.03-00:00:00',
#   'closing_time': '2015.06.04-00:00:00'},
#  {'position': 1.4005200000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.40052,
#   'sl_pos': -2.59948,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.04-00:00:00',
#   'closing_time': '2015.06.05-00:00:00'},
#  {'position': 1.39738,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.60262,
#   'sl_pos': 5.39738,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.05-00:00:00',
#   'closing_time': '2015.06.08-00:00:00'},
#  {'position': 1.39411,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.60589,
#   'sl_pos': 5.3941099999999995,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.08-00:00:00',
#   'closing_time': '2015.06.09-00:00:00'},
#  {'position': 1.40546,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.40546,
#   'sl_pos': -2.5945400000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.09-00:00:00',
#   'closing_time': '2015.06.10-00:00:00'},
#  {'position': 1.4024,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.5976,
#   'sl_pos': 5.4024,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.10-00:00:00',
#   'closing_time': '2015.06.11-00:00:00'},
#  {'position': 1.3889500000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6110499999999996,
#   'sl_pos': 5.38895,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.11-00:00:00',
#   'closing_time': '2015.06.12-00:00:00'},
#  {'position': 1.38907,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38907,
#   'sl_pos': -2.6109299999999998,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.12-00:00:00',
#   'closing_time': '2015.06.15-00:00:00'},
#  {'position': 1.3815700000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38157,
#   'sl_pos': -2.61843,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.15-00:00:00',
#   'closing_time': '2015.06.16-00:00:00'},
#  {'position': 1.3922999999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3923,
#   'sl_pos': -2.6077000000000004,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.16-00:00:00',
#   'closing_time': '2015.06.17-00:00:00'},
#  {'position': 1.3872200000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.61278,
#   'sl_pos': 5.38722,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.17-00:00:00',
#   'closing_time': '2015.06.18-00:00:00'},
#  {'position': 1.39911,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.39911,
#   'sl_pos': -2.6008899999999997,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.18-00:00:00',
#   'closing_time': '2015.06.19-00:00:00'},
#  {'position': 1.39661,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.60339,
#   'sl_pos': 5.39661,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.19-00:00:00',
#   'closing_time': '2015.06.22-00:00:00'},
#  {'position': 1.39832,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.60168,
#   'sl_pos': 5.39832,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.22-00:00:00',
#   'closing_time': '2015.06.23-00:00:00'},
#  {'position': 1.39878,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.39878,
#   'sl_pos': -2.60122,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.23-00:00:00',
#   'closing_time': '2015.06.24-00:00:00'},
#  {'position': 1.38392,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.61608,
#   'sl_pos': 5.38392,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.24-00:00:00',
#   'closing_time': '2015.06.25-00:00:00'},
#  {'position': 1.3873900000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38739,
#   'sl_pos': -2.61261,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.25-00:00:00',
#   'closing_time': '2015.06.26-00:00:00'},
#  {'position': 1.3849,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3849,
#   'sl_pos': -2.6151,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.26-00:00:00',
#   'closing_time': '2015.06.29-03:00:00'},
#  {'position': 1.35387,
#   'age': 21,
#   'type': 'BUY',
#   'tp_pos': 5.35387,
#   'sl_pos': -2.6461300000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.29-03:00:00',
#   'closing_time': '2015.06.30-00:00:00'},
#  {'position': 1.3766399999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.37664,
#   'sl_pos': -2.62336,
#   'close_status': 'eotd',
#   'opening_time': '2015.06.30-00:00:00',
#   'closing_time': '2015.07.01-00:00:00'},
#  {'position': 1.3653799999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.63462,
#   'sl_pos': 5.36538,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.01-00:00:00',
#   'closing_time': '2015.07.02-00:00:00'},
#  {'position': 1.36119,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6388100000000003,
#   'sl_pos': 5.36119,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.02-00:00:00',
#   'closing_time': '2015.07.03-00:00:00'},
#  {'position': 1.36396,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3639600000000005,
#   'sl_pos': -2.63604,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.03-00:00:00',
#   'closing_time': '2015.07.06-00:00:00'},
#  {'position': 1.3395,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3395,
#   'sl_pos': -2.6605,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.06-00:00:00',
#   'closing_time': '2015.07.07-00:00:00'},
#  {'position': 1.3549,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6451000000000002,
#   'sl_pos': 5.3549,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.07-00:00:00',
#   'closing_time': '2015.07.08-00:00:00'},
#  {'position': 1.3488399999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65116,
#   'sl_pos': 5.34884,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.08-00:00:00',
#   'closing_time': '2015.07.09-00:00:00'},
#  {'position': 1.3369,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6631,
#   'sl_pos': 5.3369,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.09-00:00:00',
#   'closing_time': '2015.07.10-00:00:00'},
#  {'position': 1.33876,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6612400000000003,
#   'sl_pos': 5.33876,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.10-00:00:00',
#   'closing_time': '2015.07.13-00:00:00'},
#  {'position': 1.35738,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35738,
#   'sl_pos': -2.64262,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.13-00:00:00',
#   'closing_time': '2015.07.14-00:00:00'},
#  {'position': 1.35775,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6422499999999998,
#   'sl_pos': 5.35775,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.14-00:00:00',
#   'closing_time': '2015.07.15-00:00:00'},
#  {'position': 1.35803,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6419699999999997,
#   'sl_pos': 5.35803,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.15-00:00:00',
#   'closing_time': '2015.07.16-00:00:00'},
#  {'position': 1.3547299999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35473,
#   'sl_pos': -2.64527,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.16-00:00:00',
#   'closing_time': '2015.07.17-00:00:00'},
#  {'position': 1.34971,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65029,
#   'sl_pos': 5.34971,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.17-00:00:00',
#   'closing_time': '2015.07.20-00:00:00'},
#  {'position': 1.3437299999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65627,
#   'sl_pos': 5.34373,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.20-00:00:00',
#   'closing_time': '2015.07.21-00:00:00'},
#  {'position': 1.34491,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3449100000000005,
#   'sl_pos': -2.65509,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.21-00:00:00',
#   'closing_time': '2015.07.22-00:00:00'},
#  {'position': 1.35429,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35429,
#   'sl_pos': -2.6457100000000002,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.22-00:00:00',
#   'closing_time': '2015.07.23-00:00:00'},
#  {'position': 1.3544,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3544,
#   'sl_pos': -2.6456,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.23-00:00:00',
#   'closing_time': '2015.07.24-00:00:00'},
#  {'position': 1.3598,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6402,
#   'sl_pos': 5.3598,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.24-00:00:00',
#   'closing_time': '2015.07.27-00:00:00'},
#  {'position': 1.35863,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35863,
#   'sl_pos': -2.64137,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.27-00:00:00',
#   'closing_time': '2015.07.28-00:00:00'},
#  {'position': 1.36635,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36635,
#   'sl_pos': -2.6336500000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.28-00:00:00',
#   'closing_time': '2015.07.29-00:00:00'},
#  {'position': 1.36635,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6336500000000003,
#   'sl_pos': 5.36635,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.29-00:00:00',
#   'closing_time': '2015.07.30-00:00:00'},
#  {'position': 1.36084,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.63916,
#   'sl_pos': 5.36084,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.30-00:00:00',
#   'closing_time': '2015.07.31-00:00:00'},
#  {'position': 1.3567799999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6432200000000003,
#   'sl_pos': 5.35678,
#   'close_status': 'eotd',
#   'opening_time': '2015.07.31-00:00:00',
#   'closing_time': '2015.08.03-00:00:00'},
#  {'position': 1.35959,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64041,
#   'sl_pos': 5.35959,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.03-00:00:00',
#   'closing_time': '2015.08.04-00:00:00'},
#  {'position': 1.3578899999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64211,
#   'sl_pos': 5.357889999999999,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.04-00:00:00',
#   'closing_time': '2015.08.05-00:00:00'},
#  {'position': 1.3531799999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64682,
#   'sl_pos': 5.35318,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.05-00:00:00',
#   'closing_time': '2015.08.06-00:00:00'},
#  {'position': 1.3613399999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36134,
#   'sl_pos': -2.6386600000000002,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.06-00:00:00',
#   'closing_time': '2015.08.07-00:00:00'},
#  {'position': 1.3621100000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36211,
#   'sl_pos': -2.6378899999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.07-00:00:00',
#   'closing_time': '2015.08.10-00:00:00'},
#  {'position': 1.3611099999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.63889,
#   'sl_pos': 5.36111,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.10-00:00:00',
#   'closing_time': '2015.08.11-00:00:00'},
#  {'position': 1.37274,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.37274,
#   'sl_pos': -2.6272599999999997,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.11-00:00:00',
#   'closing_time': '2015.08.12-00:00:00'},
#  {'position': 1.3812799999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38128,
#   'sl_pos': -2.61872,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.12-00:00:00',
#   'closing_time': '2015.08.13-00:00:00'},
#  {'position': 1.38549,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.61451,
#   'sl_pos': 5.38549,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.13-00:00:00',
#   'closing_time': '2015.08.14-00:00:00'},
#  {'position': 1.38691,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38691,
#   'sl_pos': -2.6130899999999997,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.14-00:00:00',
#   'closing_time': '2015.08.17-00:00:00'},
#  {'position': 1.38132,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.61868,
#   'sl_pos': 5.3813200000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.17-00:00:00',
#   'closing_time': '2015.08.18-00:00:00'},
#  {'position': 1.3775,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6225,
#   'sl_pos': 5.3774999999999995,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.18-00:00:00',
#   'closing_time': '2015.08.19-00:00:00'},
#  {'position': 1.37148,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.62852,
#   'sl_pos': 5.37148,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.19-00:00:00',
#   'closing_time': '2015.08.20-00:00:00'},
#  {'position': 1.37624,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.37624,
#   'sl_pos': -2.62376,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.20-00:00:00',
#   'closing_time': '2015.08.21-00:00:00'},
#  {'position': 1.38659,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38659,
#   'sl_pos': -2.61341,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.21-00:00:00',
#   'closing_time': '2015.08.24-00:00:00'},
#  {'position': 1.38612,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.38612,
#   'sl_pos': -2.61388,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.24-00:00:00',
#   'closing_time': '2015.08.25-00:00:00'},
#  {'position': 1.37535,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.62465,
#   'sl_pos': 5.37535,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.25-00:00:00',
#   'closing_time': '2015.08.26-00:00:00'},
#  {'position': 1.3688399999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6311600000000004,
#   'sl_pos': 5.36884,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.26-00:00:00',
#   'closing_time': '2015.08.27-00:00:00'},
#  {'position': 1.3565,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6435,
#   'sl_pos': 5.3565000000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.27-00:00:00',
#   'closing_time': '2015.08.28-00:00:00'},
#  {'position': 1.36054,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36054,
#   'sl_pos': -2.6394599999999997,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.28-00:00:00',
#   'closing_time': '2015.08.31-00:00:00'},
#  {'position': 1.35886,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35886,
#   'sl_pos': -2.64114,
#   'close_status': 'eotd',
#   'opening_time': '2015.08.31-00:00:00',
#   'closing_time': '2015.09.01-00:00:00'},
#  {'position': 1.3584299999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64157,
#   'sl_pos': 5.35843,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.01-00:00:00',
#   'closing_time': '2015.09.02-00:00:00'},
#  {'position': 1.35039,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64961,
#   'sl_pos': 5.35039,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.02-00:00:00',
#   'closing_time': '2015.09.03-00:00:00'},
#  {'position': 1.35047,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64953,
#   'sl_pos': 5.35047,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.03-00:00:00',
#   'closing_time': '2015.09.04-00:00:00'},
#  {'position': 1.33519,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.66481,
#   'sl_pos': 5.33519,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.04-00:00:00',
#   'closing_time': '2015.09.07-00:00:00'},
#  {'position': 1.3266,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6734,
#   'sl_pos': 5.3266,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.07-00:00:00',
#   'closing_time': '2015.09.08-00:00:00'},
#  {'position': 1.3317700000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.331770000000001,
#   'sl_pos': -2.66823,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.08-00:00:00',
#   'closing_time': '2015.09.09-00:00:00'},
#  {'position': 1.34161,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34161,
#   'sl_pos': -2.65839,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.09-00:00:00',
#   'closing_time': '2015.09.10-00:00:00'},
#  {'position': 1.34982,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34982,
#   'sl_pos': -2.6501799999999998,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.10-00:00:00',
#   'closing_time': '2015.09.11-00:00:00'},
#  {'position': 1.35964,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35964,
#   'sl_pos': -2.6403600000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.11-00:00:00',
#   'closing_time': '2015.09.14-00:00:00'},
#  {'position': 1.3655200000000003,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36552,
#   'sl_pos': -2.63448,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.14-00:00:00',
#   'closing_time': '2015.09.15-00:00:00'},
#  {'position': 1.3599299999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64007,
#   'sl_pos': 5.35993,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.15-00:00:00',
#   'closing_time': '2015.09.16-00:00:00'},
#  {'position': 1.3568200000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64318,
#   'sl_pos': 5.35682,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.16-00:00:00',
#   'closing_time': '2015.09.17-00:00:00'},
#  {'position': 1.3610499999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36105,
#   'sl_pos': -2.6389500000000004,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.17-00:00:00',
#   'closing_time': '2015.09.18-00:00:00'},
#  {'position': 1.3719899999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.37199,
#   'sl_pos': -2.62801,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.18-00:00:00',
#   'closing_time': '2015.09.21-00:00:00'},
#  {'position': 1.3551499999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64485,
#   'sl_pos': 5.35515,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.21-00:00:00',
#   'closing_time': '2015.09.22-00:00:00'},
#  {'position': 1.3488399999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65116,
#   'sl_pos': 5.34884,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.22-00:00:00',
#   'closing_time': '2015.09.23-00:00:00'},
#  {'position': 1.3363,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6637,
#   'sl_pos': 5.3363,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.23-00:00:00',
#   'closing_time': '2015.09.24-00:00:00'},
#  {'position': 1.3449200000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34492,
#   'sl_pos': -2.65508,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.24-00:00:00',
#   'closing_time': '2015.09.25-00:00:00'},
#  {'position': 1.34855,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3485499999999995,
#   'sl_pos': -2.65145,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.25-00:00:00',
#   'closing_time': '2015.09.28-00:00:00'},
#  {'position': 1.34794,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3479399999999995,
#   'sl_pos': -2.65206,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.28-00:00:00',
#   'closing_time': '2015.09.29-00:00:00'},
#  {'position': 1.3481100000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34811,
#   'sl_pos': -2.65189,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.29-00:00:00',
#   'closing_time': '2015.09.30-00:00:00'},
#  {'position': 1.3466399999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65336,
#   'sl_pos': 5.34664,
#   'close_status': 'eotd',
#   'opening_time': '2015.09.30-00:00:00',
#   'closing_time': '2015.10.01-00:00:00'},
#  {'position': 1.3396100000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6603899999999996,
#   'sl_pos': 5.33961,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.01-00:00:00',
#   'closing_time': '2015.10.02-00:00:00'},
#  {'position': 1.3419999999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.342,
#   'sl_pos': -2.6580000000000004,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.02-00:00:00',
#   'closing_time': '2015.10.05-00:00:00'},
#  {'position': 1.3465,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6535,
#   'sl_pos': 5.3465,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.05-00:00:00',
#   'closing_time': '2015.10.06-00:00:00'},
#  {'position': 1.34732,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65268,
#   'sl_pos': 5.34732,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.06-00:00:00',
#   'closing_time': '2015.10.07-00:00:00'},
#  {'position': 1.35482,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35482,
#   'sl_pos': -2.64518,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.07-00:00:00',
#   'closing_time': '2015.10.08-00:00:00'},
#  {'position': 1.34839,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.65161,
#   'sl_pos': 5.34839,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.08-00:00:00',
#   'closing_time': '2015.10.09-00:00:00'},
#  {'position': 1.35202,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64798,
#   'sl_pos': 5.3520199999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.09-00:00:00',
#   'closing_time': '2015.10.12-00:00:00'},
#  {'position': 1.36493,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.36493,
#   'sl_pos': -2.63507,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.12-00:00:00',
#   'closing_time': '2015.10.13-00:00:00'},
#  {'position': 1.3630600000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.63694,
#   'sl_pos': 5.36306,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.13-00:00:00',
#   'closing_time': '2015.10.14-00:00:00'},
#  {'position': 1.36222,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6377800000000002,
#   'sl_pos': 5.36222,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.14-00:00:00',
#   'closing_time': '2015.10.15-00:00:00'},
#  {'position': 1.3630000000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.363,
#   'sl_pos': -2.6369999999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.15-00:00:00',
#   'closing_time': '2015.10.16-00:00:00'},
#  {'position': 1.3542700000000003,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6457299999999995,
#   'sl_pos': 5.3542700000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.16-00:00:00',
#   'closing_time': '2015.10.19-00:00:00'},
#  {'position': 1.3555200000000003,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6444799999999997,
#   'sl_pos': 5.35552,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.19-00:00:00',
#   'closing_time': '2015.10.20-00:00:00'},
#  {'position': 1.35287,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35287,
#   'sl_pos': -2.6471299999999998,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.20-00:00:00',
#   'closing_time': '2015.10.21-00:00:00'},
#  {'position': 1.3592700000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.35927,
#   'sl_pos': -2.6407299999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.21-00:00:00',
#   'closing_time': '2015.10.22-00:00:00'},
#  {'position': 1.35956,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.64044,
#   'sl_pos': 5.35956,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.22-00:00:00',
#   'closing_time': '2015.10.23-00:00:00'},
#  {'position': 1.3405,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6595,
#   'sl_pos': 5.3405000000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.23-00:00:00',
#   'closing_time': '2015.10.26-00:00:00'},
#  {'position': 1.33697,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.33697,
#   'sl_pos': -2.66303,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.26-00:00:00',
#   'closing_time': '2015.10.27-00:00:00'},
#  {'position': 1.3373599999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.33736,
#   'sl_pos': -2.66264,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.27-00:00:00',
#   'closing_time': '2015.10.28-00:00:00'},
#  {'position': 1.32968,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6703200000000002,
#   'sl_pos': 5.32968,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.28-00:00:00',
#   'closing_time': '2015.10.29-00:00:00'},
#  {'position': 1.3233199999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.67668,
#   'sl_pos': 5.32332,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.29-00:00:00',
#   'closing_time': '2015.10.30-00:00:00'},
#  {'position': 1.3299200000000002,
#   'age': 23,
#   'type': 'BUY',
#   'tp_pos': 5.32992,
#   'sl_pos': -2.6700799999999996,
#   'close_status': 'eotd',
#   'opening_time': '2015.10.30-00:00:00',
#   'closing_time': '2015.11.02-00:00:00'},
#  {'position': 1.3288299999999997,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.67117,
#   'sl_pos': 5.32883,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.02-00:00:00',
#   'closing_time': '2015.11.03-00:00:00'},
#  {'position': 1.3298699999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6701300000000003,
#   'sl_pos': 5.32987,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.03-00:00:00',
#   'closing_time': '2015.11.04-00:00:00'},
#  {'position': 1.3273400000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6726599999999996,
#   'sl_pos': 5.32734,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.04-00:00:00',
#   'closing_time': '2015.11.05-00:00:00'},
#  {'position': 1.3206499999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6793500000000003,
#   'sl_pos': 5.32065,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.05-00:00:00',
#   'closing_time': '2015.11.06-00:00:00'},
#  {'position': 1.32447,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.32447,
#   'sl_pos': -2.67553,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.06-00:00:00',
#   'closing_time': '2015.11.09-00:00:00'},
#  {'position': 1.32275,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.32275,
#   'sl_pos': -2.67725,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.09-00:00:00',
#   'closing_time': '2015.11.10-00:00:00'},
#  {'position': 1.3237200000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6762799999999998,
#   'sl_pos': 5.32372,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.10-00:00:00',
#   'closing_time': '2015.11.11-00:00:00'},
#  {'position': 1.32018,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6798200000000003,
#   'sl_pos': 5.32018,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.11-00:00:00',
#   'closing_time': '2015.11.12-00:00:00'},
#  {'position': 1.31914,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.68086,
#   'sl_pos': 5.31914,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.12-00:00:00',
#   'closing_time': '2015.11.13-00:00:00'},
#  {'position': 1.32503,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.32503,
#   'sl_pos': -2.67497,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.13-00:00:00',
#   'closing_time': '2015.11.16-00:00:00'},
#  {'position': 1.31241,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.68759,
#   'sl_pos': 5.31241,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.16-00:00:00',
#   'closing_time': '2015.11.17-00:00:00'},
#  {'position': 1.3162399999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6837600000000004,
#   'sl_pos': 5.31624,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.17-00:00:00',
#   'closing_time': '2015.11.18-00:00:00'},
#  {'position': 1.3134299999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.68657,
#   'sl_pos': 5.31343,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.18-00:00:00',
#   'closing_time': '2015.11.19-00:00:00'},
#  {'position': 1.3172899999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.31729,
#   'sl_pos': -2.68271,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.19-00:00:00',
#   'closing_time': '2015.11.20-00:00:00'},
#  {'position': 1.3183700000000003,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6816299999999997,
#   'sl_pos': 5.31837,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.20-00:00:00',
#   'closing_time': '2015.11.23-00:00:00'},
#  {'position': 1.30685,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69315,
#   'sl_pos': 5.30685,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.23-00:00:00',
#   'closing_time': '2015.11.24-00:00:00'},
#  {'position': 1.30655,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.30655,
#   'sl_pos': -2.69345,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.24-00:00:00',
#   'closing_time': '2015.11.25-00:00:00'},
#  {'position': 1.30433,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69567,
#   'sl_pos': 5.30433,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.25-00:00:00',
#   'closing_time': '2015.11.26-00:00:00'},
#  {'position': 1.3027700000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.302770000000001,
#   'sl_pos': -2.69723,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.26-00:00:00',
#   'closing_time': '2015.11.27-00:00:00'},
#  {'position': 1.30119,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69881,
#   'sl_pos': 5.30119,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.27-00:00:00',
#   'closing_time': '2015.11.30-00:00:00'},
#  {'position': 1.30042,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.30042,
#   'sl_pos': -2.69958,
#   'close_status': 'eotd',
#   'opening_time': '2015.11.30-00:00:00',
#   'closing_time': '2015.12.01-00:00:00'},
#  {'position': 1.29994,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7000599999999997,
#   'sl_pos': 5.29994,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.01-00:00:00',
#   'closing_time': '2015.12.02-00:00:00'},
#  {'position': 1.30636,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.30636,
#   'sl_pos': -2.6936400000000003,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.02-00:00:00',
#   'closing_time': '2015.12.03-00:00:00'},
#  {'position': 1.3083700000000003,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.30837,
#   'sl_pos': -2.69163,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.03-00:00:00',
#   'closing_time': '2015.12.04-00:00:00'},
#  {'position': 1.3407900000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.34079,
#   'sl_pos': -2.65921,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.04-00:00:00',
#   'closing_time': '2015.12.07-00:00:00'},
#  {'position': 1.33904,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.66096,
#   'sl_pos': 5.33904,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.07-00:00:00',
#   'closing_time': '2015.12.08-00:00:00'},
#  {'position': 1.33668,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6633199999999997,
#   'sl_pos': 5.33668,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.08-00:00:00',
#   'closing_time': '2015.12.09-00:00:00'},
#  {'position': 1.33857,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.66143,
#   'sl_pos': 5.33857,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.09-00:00:00',
#   'closing_time': '2015.12.10-00:00:00'},
#  {'position': 1.33875,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.33875,
#   'sl_pos': -2.66125,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.10-00:00:00',
#   'closing_time': '2015.12.11-00:00:00'},
#  {'position': 1.3296200000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6703799999999998,
#   'sl_pos': 5.32962,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.11-00:00:00',
#   'closing_time': '2015.12.14-00:00:00'},
#  {'position': 1.33048,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.66952,
#   'sl_pos': 5.33048,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.14-00:00:00',
#   'closing_time': '2015.12.15-00:00:00'},
#  {'position': 1.33019,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.33019,
#   'sl_pos': -2.66981,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.15-00:00:00',
#   'closing_time': '2015.12.16-00:00:00'},
#  {'position': 1.32924,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.67076,
#   'sl_pos': 5.32924,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.16-00:00:00',
#   'closing_time': '2015.12.17-00:00:00'},
#  {'position': 1.33341,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.33341,
#   'sl_pos': -2.6665900000000002,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.17-00:00:00',
#   'closing_time': '2015.12.18-00:00:00'},
#  {'position': 1.3264799999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.67352,
#   'sl_pos': 5.32648,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.18-00:00:00',
#   'closing_time': '2015.12.21-00:00:00'},
#  {'position': 1.31549,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.68451,
#   'sl_pos': 5.3154900000000005,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.21-00:00:00',
#   'closing_time': '2015.12.22-00:00:00'},
#  {'position': 1.3222999999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.3223,
#   'sl_pos': -2.6777,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.22-00:00:00',
#   'closing_time': '2015.12.23-00:00:00'},
#  {'position': 1.32558,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.32558,
#   'sl_pos': -2.67442,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.23-00:00:00',
#   'closing_time': '2015.12.24-00:00:00'},
#  {'position': 1.31918,
#   'age': 19,
#   'type': 'SELL',
#   'tp_pos': -2.6808199999999998,
#   'sl_pos': 5.31918,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.24-00:00:00',
#   'closing_time': '2015.12.28-00:00:00'},
#  {'position': 1.3159999999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.316,
#   'sl_pos': -2.684,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.28-00:00:00',
#   'closing_time': '2015.12.29-00:00:00'},
#  {'position': 1.32035,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.67965,
#   'sl_pos': 5.3203499999999995,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.29-00:00:00',
#   'closing_time': '2015.12.30-00:00:00'},
#  {'position': 1.31559,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6844099999999997,
#   'sl_pos': 5.31559,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.30-00:00:00',
#   'closing_time': '2015.12.31-00:00:00'},
#  {'position': 1.317,
#   'age': 21,
#   'type': 'BUY',
#   'tp_pos': 5.317,
#   'sl_pos': -2.683,
#   'close_status': 'eotd',
#   'opening_time': '2015.12.31-00:00:00',
#   'closing_time': '2016.01.04-00:00:00'},
#  {'position': 1.30657,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69343,
#   'sl_pos': 5.30657,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.04-00:00:00',
#   'closing_time': '2016.01.05-00:00:00'},
#  {'position': 1.29303,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70697,
#   'sl_pos': 5.29303,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.05-00:00:00',
#   'closing_time': '2016.01.06-00:00:00'},
#  {'position': 1.27893,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72107,
#   'sl_pos': 5.27893,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.06-00:00:00',
#   'closing_time': '2016.01.07-00:00:00'},
#  {'position': 1.27693,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27693,
#   'sl_pos': -2.72307,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.07-00:00:00',
#   'closing_time': '2016.01.08-00:00:00'},
#  {'position': 1.28494,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28494,
#   'sl_pos': -2.7150600000000003,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.08-00:00:00',
#   'closing_time': '2016.01.11-00:00:00'},
#  {'position': 1.27888,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72112,
#   'sl_pos': 5.27888,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.11-00:00:00',
#   'closing_time': '2016.01.12-00:00:00'},
#  {'position': 1.27868,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72132,
#   'sl_pos': 5.27868,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.12-00:00:00',
#   'closing_time': '2016.01.13-00:00:00'},
#  {'position': 1.2766899999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72331,
#   'sl_pos': 5.27669,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.13-00:00:00',
#   'closing_time': '2016.01.14-00:00:00'},
#  {'position': 1.2797200000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27972,
#   'sl_pos': -2.72028,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.14-00:00:00',
#   'closing_time': '2016.01.15-00:00:00'},
#  {'position': 1.2817600000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28176,
#   'sl_pos': -2.7182399999999998,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.15-00:00:00',
#   'closing_time': '2016.01.18-00:00:00'},
#  {'position': 1.2745900000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72541,
#   'sl_pos': 5.27459,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.18-00:00:00',
#   'closing_time': '2016.01.19-00:00:00'},
#  {'position': 1.2776299999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27763,
#   'sl_pos': -2.72237,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.19-00:00:00',
#   'closing_time': '2016.01.20-00:00:00'},
#  {'position': 1.28243,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28243,
#   'sl_pos': -2.7175700000000003,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.20-00:00:00',
#   'closing_time': '2016.01.21-00:00:00'},
#  {'position': 1.27308,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72692,
#   'sl_pos': 5.27308,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.21-00:00:00',
#   'closing_time': '2016.01.22-00:00:00'},
#  {'position': 1.2797100000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27971,
#   'sl_pos': -2.72029,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.22-00:00:00',
#   'closing_time': '2016.01.25-00:00:00'},
#  {'position': 1.2801099999999999,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28011,
#   'sl_pos': -2.7198900000000004,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.25-00:00:00',
#   'closing_time': '2016.01.26-00:00:00'},
#  {'position': 1.2832,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7168,
#   'sl_pos': 5.2832,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.26-00:00:00',
#   'closing_time': '2016.01.27-00:00:00'},
#  {'position': 1.287,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.287,
#   'sl_pos': -2.713,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.27-00:00:00',
#   'closing_time': '2016.01.28-00:00:00'},
#  {'position': 1.29235,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29235,
#   'sl_pos': -2.70765,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.28-00:00:00',
#   'closing_time': '2016.01.29-00:00:00'},
#  {'position': 1.29968,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29968,
#   'sl_pos': -2.70032,
#   'close_status': 'eotd',
#   'opening_time': '2016.01.29-00:00:00',
#   'closing_time': '2016.02.01-00:00:00'},
#  {'position': 1.3139600000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.31396,
#   'sl_pos': -2.6860399999999998,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.01-00:00:00',
#   'closing_time': '2016.02.02-00:00:00'},
#  {'position': 1.3169399999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.31694,
#   'sl_pos': -2.6830600000000002,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.02-00:00:00',
#   'closing_time': '2016.02.03-00:00:00'},
#  {'position': 1.3095500000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69045,
#   'sl_pos': 5.30955,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.03-00:00:00',
#   'closing_time': '2016.02.04-00:00:00'},
#  {'position': 1.30873,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.30873,
#   'sl_pos': -2.6912700000000003,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.04-00:00:00',
#   'closing_time': '2016.02.05-00:00:00'},
#  {'position': 1.30856,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.69144,
#   'sl_pos': 5.30856,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.05-00:00:00',
#   'closing_time': '2016.02.08-00:00:00'},
#  {'position': 1.30141,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.6985900000000003,
#   'sl_pos': 5.30141,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.08-00:00:00',
#   'closing_time': '2016.02.09-00:00:00'},
#  {'position': 1.29654,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7034599999999998,
#   'sl_pos': 5.29654,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.09-00:00:00',
#   'closing_time': '2016.02.10-00:00:00'},
#  {'position': 1.2991899999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.299189999999999,
#   'sl_pos': -2.70081,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.10-00:00:00',
#   'closing_time': '2016.02.11-00:00:00'},
#  {'position': 1.2795200000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72048,
#   'sl_pos': 5.27952,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.11-00:00:00',
#   'closing_time': '2016.02.12-00:00:00'},
#  {'position': 1.2726,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.2726,
#   'sl_pos': -2.7274000000000003,
#   'close_status': 'eotd',
#   'opening_time': '2016.02.12-00:00:00',
#   'closing_time': '2016.02.15-00:00:00'},
#  {'position': 1.2737100000000001,
#   'age': 24,
# ...
#   'close_status': 'eotd',
#   'opening_time': '2018.10.09-00:00:00',
#   'closing_time': '2018.10.10-00:00:00'},
#  {'position': 1.29775,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7022500000000003,
#   'sl_pos': 5.29775,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.10-00:00:00',
#   'closing_time': '2018.10.11-00:00:00'},
#  {'position': 1.29332,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70668,
#   'sl_pos': 5.29332,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.11-00:00:00',
#   'closing_time': '2018.10.12-00:00:00'},
#  {'position': 1.2990700000000002,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29907,
#   'sl_pos': -2.7009299999999996,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.12-00:00:00',
#   'closing_time': '2018.10.15-00:00:00'},
#  {'position': 1.29385,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70615,
#   'sl_pos': 5.29385,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.15-00:00:00',
#   'closing_time': '2018.10.16-00:00:00'},
#  {'position': 1.2940399999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70596,
#   'sl_pos': 5.29404,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.16-00:00:00',
#   'closing_time': '2018.10.17-00:00:00'},
#  {'position': 1.2990799999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29908,
#   'sl_pos': -2.70092,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.17-00:00:00',
#   'closing_time': '2018.10.18-00:00:00'},
#  {'position': 1.2953299999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70467,
#   'sl_pos': 5.29533,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.18-00:00:00',
#   'closing_time': '2018.10.19-00:00:00'},
#  {'position': 1.28458,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71542,
#   'sl_pos': 5.28458,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.19-00:00:00',
#   'closing_time': '2018.10.22-00:00:00'},
#  {'position': 1.29629,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29629,
#   'sl_pos': -2.70371,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.22-00:00:00',
#   'closing_time': '2018.10.23-00:00:00'},
#  {'position': 1.29329,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70671,
#   'sl_pos': 5.29329,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.23-00:00:00',
#   'closing_time': '2018.10.24-00:00:00'},
#  {'position': 1.28965,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71035,
#   'sl_pos': 5.28965,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.24-00:00:00',
#   'closing_time': '2018.10.25-00:00:00'},
#  {'position': 1.27829,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72171,
#   'sl_pos': 5.27829,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.25-00:00:00',
#   'closing_time': '2018.10.26-00:00:00'},
#  {'position': 1.27837,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27837,
#   'sl_pos': -2.72163,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.26-00:00:00',
#   'closing_time': '2018.10.29-00:00:00'},
#  {'position': 1.27534,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27534,
#   'sl_pos': -2.72466,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.29-00:00:00',
#   'closing_time': '2018.10.30-00:00:00'},
#  {'position': 1.27768,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72232,
#   'sl_pos': 5.27768,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.30-00:00:00',
#   'closing_time': '2018.10.31-00:00:00'},
#  {'position': 1.2827600000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28276,
#   'sl_pos': -2.71724,
#   'close_status': 'eotd',
#   'opening_time': '2018.10.31-00:00:00',
#   'closing_time': '2018.11.01-00:00:00'},
#  {'position': 1.2776,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7224,
#   'sl_pos': 5.2776,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.01-00:00:00',
#   'closing_time': '2018.11.02-00:00:00'},
#  {'position': 1.2843799999999999,
#   'age': 23,
#   'type': 'BUY',
#   'tp_pos': 5.28438,
#   'sl_pos': -2.7156200000000004,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.02-00:00:00',
#   'closing_time': '2018.11.05-00:00:00'},
#  {'position': 1.28815,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28815,
#   'sl_pos': -2.71185,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.05-00:00:00',
#   'closing_time': '2018.11.06-00:00:00'},
#  {'position': 1.29108,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29108,
#   'sl_pos': -2.70892,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.06-00:00:00',
#   'closing_time': '2018.11.07-00:00:00'},
#  {'position': 1.2959,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.2959,
#   'sl_pos': -2.7041,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.07-00:00:00',
#   'closing_time': '2018.11.08-00:00:00'},
#  {'position': 1.29709,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.70291,
#   'sl_pos': 5.29709,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.08-00:00:00',
#   'closing_time': '2018.11.09-00:00:00'},
#  {'position': 1.2961,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7039,
#   'sl_pos': 5.2961,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.09-00:00:00',
#   'closing_time': '2018.11.12-00:00:00'},
#  {'position': 1.28793,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7120699999999998,
#   'sl_pos': 5.28793,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.12-00:00:00',
#   'closing_time': '2018.11.13-00:00:00'},
#  {'position': 1.2768700000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72313,
#   'sl_pos': 5.276870000000001,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.13-00:00:00',
#   'closing_time': '2018.11.14-00:00:00'},
#  {'position': 1.28488,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28488,
#   'sl_pos': -2.7151199999999998,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.14-00:00:00',
#   'closing_time': '2018.11.15-00:00:00'},
#  {'position': 1.2849899999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7150100000000004,
#   'sl_pos': 5.28499,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.15-00:00:00',
#   'closing_time': '2018.11.16-00:00:00'},
#  {'position': 1.28693,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28693,
#   'sl_pos': -2.71307,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.16-00:00:00',
#   'closing_time': '2018.11.19-00:00:00'},
#  {'position': 1.2869,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.2869,
#   'sl_pos': -2.7131,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.19-00:00:00',
#   'closing_time': '2018.11.20-00:00:00'},
#  {'position': 1.2890100000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71099,
#   'sl_pos': 5.28901,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.20-00:00:00',
#   'closing_time': '2018.11.21-00:00:00'},
#  {'position': 1.28207,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71793,
#   'sl_pos': 5.28207,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.21-00:00:00',
#   'closing_time': '2018.11.22-00:00:00'},
#  {'position': 1.2872899999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28729,
#   'sl_pos': -2.7127100000000004,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.22-00:00:00',
#   'closing_time': '2018.11.23-00:00:00'},
#  {'position': 1.28799,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28799,
#   'sl_pos': -2.7120100000000003,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.23-00:00:00',
#   'closing_time': '2018.11.26-00:00:00'},
#  {'position': 1.28023,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71977,
#   'sl_pos': 5.2802299999999995,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.26-00:00:00',
#   'closing_time': '2018.11.27-00:00:00'},
#  {'position': 1.28648,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28648,
#   'sl_pos': -2.71352,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.27-00:00:00',
#   'closing_time': '2018.11.28-00:00:00'},
#  {'position': 1.28451,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71549,
#   'sl_pos': 5.28451,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.28-00:00:00',
#   'closing_time': '2018.11.29-00:00:00'},
#  {'position': 1.2920500000000001,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29205,
#   'sl_pos': -2.70795,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.29-00:00:00',
#   'closing_time': '2018.11.30-00:00:00'},
#  {'position': 1.29272,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29272,
#   'sl_pos': -2.70728,
#   'close_status': 'eotd',
#   'opening_time': '2018.11.30-00:00:00',
#   'closing_time': '2018.12.03-00:00:00'},
#  {'position': 1.29043,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7095700000000003,
#   'sl_pos': 5.29043,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.03-00:00:00',
#   'closing_time': '2018.12.04-00:00:00'},
#  {'position': 1.29013,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.2901299999999996,
#   'sl_pos': -2.70987,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.04-00:00:00',
#   'closing_time': '2018.12.05-00:00:00'},
#  {'position': 1.2790700000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72093,
#   'sl_pos': 5.27907,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.05-00:00:00',
#   'closing_time': '2018.12.06-00:00:00'},
#  {'position': 1.28404,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28404,
#   'sl_pos': -2.71596,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.06-00:00:00',
#   'closing_time': '2018.12.07-00:00:00'},
#  {'position': 1.28186,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28186,
#   'sl_pos': -2.71814,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.07-00:00:00',
#   'closing_time': '2018.12.10-00:00:00'},
#  {'position': 1.2819899999999997,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7180100000000005,
#   'sl_pos': 5.2819899999999995,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.10-00:00:00',
#   'closing_time': '2018.12.11-00:00:00'},
#  {'position': 1.28662,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28662,
#   'sl_pos': -2.71338,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.11-00:00:00',
#   'closing_time': '2018.12.12-00:00:00'},
#  {'position': 1.28329,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71671,
#   'sl_pos': 5.28329,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.12-00:00:00',
#   'closing_time': '2018.12.13-00:00:00'},
#  {'position': 1.28765,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.28765,
#   'sl_pos': -2.71235,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.13-00:00:00',
#   'closing_time': '2018.12.14-00:00:00'},
#  {'position': 1.29033,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.29033,
#   'sl_pos': -2.70967,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.14-00:00:00',
#   'closing_time': '2018.12.17-00:00:00'},
#  {'position': 1.2809899999999999,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71901,
#   'sl_pos': 5.28099,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.17-00:00:00',
#   'closing_time': '2018.12.18-00:00:00'},
#  {'position': 1.2802200000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.71978,
#   'sl_pos': 5.28022,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.18-00:00:00',
#   'closing_time': '2018.12.19-00:00:00'},
#  {'position': 1.27863,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.7213700000000003,
#   'sl_pos': 5.27863,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.19-00:00:00',
#   'closing_time': '2018.12.20-00:00:00'},
#  {'position': 1.27949,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.27949,
#   'sl_pos': -2.72051,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.20-00:00:00',
#   'closing_time': '2018.12.21-00:00:00'},
#  {'position': 1.27384,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.72616,
#   'sl_pos': 5.27384,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.21-00:00:00',
#   'closing_time': '2018.12.24-00:00:00'},
#  {'position': 1.26397,
#   'age': 21,
#   'type': 'SELL',
#   'tp_pos': -2.73603,
#   'sl_pos': 5.2639700000000005,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.24-00:00:00',
#   'closing_time': '2018.12.26-05:00:00'},
#  {'position': 1.26029,
#   'age': 19,
#   'type': 'SELL',
#   'tp_pos': -2.73971,
#   'sl_pos': 5.2602899999999995,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.26-05:00:00',
#   'closing_time': '2018.12.27-00:00:00'},
#  {'position': 1.26411,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.2641100000000005,
#   'sl_pos': -2.73589,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.27-00:00:00',
#   'closing_time': '2018.12.28-00:00:00'},
#  {'position': 1.2690899999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.26909,
#   'sl_pos': -2.73091,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.28-00:00:00',
#   'closing_time': '2018.12.31-00:00:00'},
#  {'position': 1.2611700000000001,
#   'age': 23,
#   'type': 'SELL',
#   'tp_pos': -2.73883,
#   'sl_pos': 5.26117,
#   'close_status': 'eotd',
#   'opening_time': '2018.12.31-00:00:00',
#   'closing_time': '2019.01.02-06:00:00'},
#  {'position': 1.25265,
#   'age': 18,
#   'type': 'SELL',
#   'tp_pos': -2.74735,
#   'sl_pos': 5.25265,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.02-06:00:00',
#   'closing_time': '2019.01.03-00:00:00'},
#  {'position': 1.23538,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.76462,
#   'sl_pos': 5.23538,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.03-00:00:00',
#   'closing_time': '2019.01.04-00:00:00'},
#  {'position': 1.2263799999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.22638,
#   'sl_pos': -2.77362,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.04-00:00:00',
#   'closing_time': '2019.01.07-00:00:00'},
#  {'position': 1.2362799999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.23628,
#   'sl_pos': -2.76372,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.07-00:00:00',
#   'closing_time': '2019.01.08-00:00:00'},
#  {'position': 1.24743,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.24743,
#   'sl_pos': -2.75257,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.08-00:00:00',
#   'closing_time': '2019.01.09-00:00:00'},
#  {'position': 1.2439200000000001,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75608,
#   'sl_pos': 5.24392,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.09-00:00:00',
#   'closing_time': '2019.01.10-00:00:00'},
#  {'position': 1.2482799999999998,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75172,
#   'sl_pos': 5.248279999999999,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.10-00:00:00',
#   'closing_time': '2019.01.11-00:00:00'},
#  {'position': 1.24696,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75304,
#   'sl_pos': 5.24696,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.11-00:00:00',
#   'closing_time': '2019.01.14-00:00:00'},
#  {'position': 1.2431100000000002,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75689,
#   'sl_pos': 5.24311,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.14-00:00:00',
#   'closing_time': '2019.01.15-00:00:00'},
#  {'position': 1.24041,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75959,
#   'sl_pos': 5.24041,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.15-00:00:00',
#   'closing_time': '2019.01.16-00:00:00'},
#  {'position': 1.24038,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.24038,
#   'sl_pos': -2.75962,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.16-00:00:00',
#   'closing_time': '2019.01.17-00:00:00'},
#  {'position': 1.24266,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.24266,
#   'sl_pos': -2.75734,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.17-00:00:00',
#   'closing_time': '2019.01.18-00:00:00'},
#  {'position': 1.24403,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75597,
#   'sl_pos': 5.24403,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.18-00:00:00',
#   'closing_time': '2019.01.21-00:00:00'},
#  {'position': 1.24577,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.24577,
#   'sl_pos': -2.7542299999999997,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.21-00:00:00',
#   'closing_time': '2019.01.22-00:00:00'},
#  {'position': 1.24627,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75373,
#   'sl_pos': 5.24627,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.22-00:00:00',
#   'closing_time': '2019.01.23-00:00:00'},
#  {'position': 1.24223,
#   'age': 24,
#   'type': 'SELL',
#   'tp_pos': -2.75777,
#   'sl_pos': 5.24223,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.23-00:00:00',
#   'closing_time': '2019.01.24-00:00:00'},
#  {'position': 1.2473299999999998,
#   'age': 24,
#   'type': 'BUY',
#   'tp_pos': 5.24733,
#   'sl_pos': -2.75267,
#   'close_status': 'eotd',
#   'opening_time': '2019.01.24-00:00:00',
#   'closing_time': '2019.01.25-00:00:00'}]
